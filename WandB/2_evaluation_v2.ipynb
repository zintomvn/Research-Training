# %%
import os
import wandb
import weave
# from openai import OpenAI
import torch

# %%
os.environ["WANDB_API_KEY"]="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"
print(os.environ.get("WANDB_API_KEY"))
# Out:
# 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

# %%
PROJECT_NAME = "mnist-wandb-evaluation-v2"
ENTITY = "zintomfromnowhere"
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(DEVICE)

wandb.login()
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# cuda
# wandb: Currently logged in as: zintom69 (zintomfromnowhere) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
config = {
    

}
